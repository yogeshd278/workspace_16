# %% [markdown]
# <a href="https://colab.research.google.com/github/yogeshd278/workspace_16/blob/main/Bert.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 16.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 30.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 44.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 62.0 MB/s eta 0:00:00
# ...

# %%
from transformers import  pipeline

classifier = pipeline('sentiment-analysis', model='nlptown/bert-base-multilingual-uncased-sentiment')

# %%
classifier('http://soap.ottawa-anime.org/ Dear Customer, The changes in your debit card charges applicable to your salary A/c as informed earlier, are not applicable for you. Team IDFC FIRST Bank')
# Out:
# [{'label': '1 star', 'score': 0.3905114531517029}]

# %%
classifier('cloudflare.com VICTORY IS CALLING YOU ! ADMISSION IS GOING ON B TECH/DIPLOMA/ITI IN ELITTE COLLEGE, SODEPUR,  PARGANAS(N). % PLACEMENT ASSISTANCE. ADMISSION OPEN ON FIRST CUM FIRST SERVE BASIS. VISIT WWW.PETINDIA.ORG. ANY QUERIES, PL CALL : //(PINNACCLE EDUCATIONAL TRUST)')
# Out:
# [{'label': '5 stars', 'score': 0.47705546021461487}]

# %%
classifier('dailymail.co.uk Dear Customer, You are eligible for YONO INSTA LIFE SECURE a Pure Term Insurance Policy. Lowest Rate, No Medical. Login SBI YONO App or contact any SBI Branch.')
# Out:
# [{'label': '5 stars', 'score': 0.3616391122341156}]

# %%
from transformers import AutoTokenizer, TFAutoModelForSequenceClassification

# %%
model_name = 'nlptown/bert-base-multilingual-uncased-sentiment'
model = TFAutoModelForSequenceClassification.from_pretrained(model_name, from_pt=True)
tokenizer = AutoTokenizer.from_pretrained(model_name)

classifier = pipeline('sentiment-analysis', model=model, tokenizer=tokenizer)
# Out:
# All PyTorch model weights were used when initializing TFBertForSequenceClassification.
#
# All the weights of TFBertForSequenceClassification were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertForSequenceClassification for predictions without further training.

# %%
classifier('dailymail.co.uk Dear Customer, You are eligible for YONO INSTA LIFE SECURE a Pure Term Insurance Policy. Lowest Rate, No Medical. Login SBI YONO App or contact any SBI Branch.')
# Out:
# [{'label': '5 stars', 'score': 0.3616393804550171}]
